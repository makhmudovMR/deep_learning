# %%
import matplotlib.pyplot as plt

# %%
def func(x):
    return x**2

def deriv_func(x):
    return x*2

values1 = list(range(-10, 11))

val_func = list(map(func, values1))
val_deriv = list(map(deriv_func, values1))

plt.grid(True)
plt.plot(val_func)
plt.plot(val_deriv)
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
